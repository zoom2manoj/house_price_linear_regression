# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
df_app = pd.read_csv('train.csv')
df_app_test = pd.read_csv('test.csv')
df_app.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1         190       RL         90.0    15750   Pave   NaN      Reg
# 1   2          60       RL         66.0    16226   Pave   NaN      IR3
# 2   3          20       RL        118.0    13704   Pave   NaN      IR1
# 3   4          20       RL         70.0     9800   Pave   NaN      Reg
# 4   5          75       RM         87.0    18386   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN  GdWo         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      6   2006        WD         Normal     157000
# 1      5   2007        WD         Normal     267000
# 2      1   2006        WD         Normal     205000
# 3      7   2006        WD        Abnorml     149900
# 4      5   2008        WD         Normal     295000
#
# [5 rows x 81 columns]

# %%
df_app.dtypes.head()
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# dtype: object

# %%
df_app.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1         190       RL         90.0    15750   Pave   NaN      Reg
# 1        2          60       RL         66.0    16226   Pave   NaN      IR3
# 2        3          20       RL        118.0    13704   Pave   NaN      IR1
# 3        4          20       RL         70.0     9800   Pave   NaN      Reg
# 4        5          75       RM         87.0    18386   Pave   NaN      Reg
# 5        6          20       RL         80.0    10386   Pave   NaN      Reg
# 6        7          60       RL        116.0    13474   Pave   NaN      Reg
# 7        8          50       RM          NaN     7920   Pave  Grvl      IR1
# 8        9          30       RL          NaN    12342   Pave   NaN      IR1
# 9       10          20       RL         90.0    12378   Pave   NaN      IR1
# 10      11          60       RL          NaN     7685   Pave   NaN      IR1
# 11      12          20       RL         50.0     8000   Pave   NaN      Reg
# 12      13         190       RM         65.0     7800   Pave   NaN      Reg
# 13      14          20       RL        150.0   215245   Pave   NaN      IR3
# 14      15          70       RM         60.0     9600   Pave  Grvl      Reg
# 15      16          60       RL         71.0     7795   Pave   NaN      IR1
# 16      17          60       RL         94.0    13005   Pave   NaN      IR1
# 17      18          60       FV         75.0     9000   Pave   NaN      Reg
# 18      19          60       RL         90.0     9900   Pave   NaN      Reg
# 19      20          80       RL          NaN    14115   Pave   NaN      Reg
# 20      21          60       RL        111.0    16259   Pave   NaN      Reg
# 21      22          60       RL         99.0    12099   Pave   NaN      IR1
# 22      23          60       RL         86.0    10380   Pave   NaN      IR1
# 23      24          20       RM         49.0     5820   Pave   NaN      Reg
# 24      25          80       RL         96.0    11275   Pave   NaN      Reg
# 25      26          45       RM         50.0     5000   Pave   NaN      Reg
# 26      27         120       RL         32.0    10846   Pave   NaN      IR1
# 27      28          20       RL         80.0    11600   Pave   NaN      Reg
# 28      29          75       RL          NaN    11888   Pave  Pave      IR1
# 29      30          70       RM         60.0     6402   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1130  1131          60       RL         60.0    21930   Pave   NaN      IR3
# 1131  1132         120       RL          NaN     4928   Pave   NaN      IR1
# 1132  1133          30       RL         60.0    10800   Pave  Grvl      Reg
# 1133  1134          60       RL         93.0    10261   Pave   NaN      IR1
# 1134  1135          20       RL         80.0    17400   Pave   NaN      Reg
# 1135  1136          20       RL         80.0     8400   Pave   NaN      Reg
# 1136  1137          20       RL         60.0     9000   Pave   NaN      Reg
# 1137  1138          20       RL         96.0    12444   Pave   NaN      Reg
# 1138  1139          20       RM         90.0     7407   Pave   NaN      Reg
# 1139  1140          60       RL         80.0    11584   Pave   NaN      Reg
# 1140  1141          70       RL         79.0    11526   Pave   NaN      IR1
# 1141  1142         120       RM          NaN     4426   Pave   NaN      Reg
# 1142  1143          60       FV         85.0    11003   Pave   NaN      Reg
# 1143  1144          30       RL          NaN     8854   Pave   NaN      Reg
# 1144  1145          20       RL         63.0     8500   Pave   NaN      Reg
# 1145  1146          85       RL         70.0     8400   Pave   NaN      Reg
# 1146  1147          20       RL          NaN    26142   Pave   NaN      IR1
# 1147  1148          60       RL         80.0    10000   Pave   NaN      Reg
# 1148  1149          50       RL         70.0    11767   Pave   NaN      Reg
# 1149  1150         180       RM         21.0     1533   Pave   NaN      Reg
# 1150  1151          90       RL         60.0     9000   Pave   NaN      Reg
# 1151  1152          20       RL         78.0     9262   Pave   NaN      Reg
# 1152  1153         180       RM         35.0     3675   Pave   NaN      Reg
# 1153  1154          20       RL         90.0    17217   Pave   NaN      Reg
# 1154  1155          20       FV         62.0     7500   Pave  Pave      Reg
# 1155  1156          60       RL         62.0     7917   Pave   NaN      Reg
# 1156  1157          20       RL         85.0    13175   Pave   NaN      Reg
# 1157  1158          70       RL         66.0     9042   Pave   NaN      Reg
# 1158  1159          20       RL         68.0     9717   Pave   NaN      Reg
# 1159  1160          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 2            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 3            Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 4            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 5            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 6            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 7            Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 8            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 9            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 10           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 11           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 12           Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 13           Low    AllPub    ...            0    NaN    NaN         NaN
# 14           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 15           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 16           Lvl    AllPub    ...            0    NaN  GdPrv         NaN
# 17           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 18           Low    AllPub    ...            0    NaN    NaN         NaN
# 19           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 20           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 21           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 22           Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 23           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 24           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 25           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 26           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 27           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 28           Bnk    AllPub    ...            0    NaN    NaN         NaN
# 29           Lvl    AllPub    ...            0    NaN   GdWo         NaN
# ...          ...       ...    ...          ...    ...    ...         ...
# 1130         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1131         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1132         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1133         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1134         Low    AllPub    ...            0    NaN    NaN         NaN
# 1135         Lvl    AllPub    ...            0    NaN  GdPrv         NaN
# 1136         Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 1137         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1138         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1139         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1140         Bnk    AllPub    ...            0    NaN    NaN         NaN
# 1141         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1142         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1143         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1144         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1145         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1146         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1147         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1148         Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 1149         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1150         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1151         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1152         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1153         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1154         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1155         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1156         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1157         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1158         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1159         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0      6   2006        WD         Normal     157000
# 1          0      5   2007        WD         Normal     267000
# 2          0      1   2006        WD         Normal     205000
# 3          0      7   2006        WD        Abnorml     149900
# 4          0      5   2008        WD         Normal     295000
# 5          0      7   2007        WD         Normal     305900
# 6          0      6   2007        WD         Normal     225000
# 7          0      3   2008        WD         Normal      89500
# 8          0      3   2009        WD         Normal      82500
# 9          0     11   2006        WD         Normal     360000
# 10         0      5   2006        WD         Normal     165600
# 11         0      5   2009        WD         Normal     132000
# 12         0      5   2006        WD         Normal     119900
# 13         0      6   2009        WD         Normal     375000
# 14         0      8   2006        WD         Normal     178000
# 15         0      7   2009        WD         Normal     188500
# 16         0      8   2009        WD         Normal     260000
# 17         0     12   2007        WD         Normal     270000
# 18         0      4   2009        WD         Normal     260000
# 19         0      6   2009        WD         Normal     187500
# 20         0      9   2006       New        Partial     342643
# 21         0      6   2007        WD         Normal     354000
# 22         0      8   2007        WD         Normal     301000
# 23         0      7   2006        WD         Normal     126175
# 24         0      6   2010        WD         Normal     242000
# 25         0     12   2007        WD         Normal      87000
# 26         0      5   2008       Con         Normal     324000
# 27         0      4   2006        WD         Normal     145250
# 28         0      7   2009        WD         Normal     214500
# 29         0      7   2009        WD         Normal      78000
# ...      ...    ...    ...       ...            ...        ...
# 1130       0      7   2006        WD         Normal     192140
# 1131       0     10   2009        WD         Normal     143750
# 1132       0      8   2007        WD         Normal      64500
# 1133       0      5   2008        WD         Normal     186500
# 1134       0      5   2006        WD         Normal     160000
# 1135       0      7   2008       COD        Abnorml     174000
# 1136       0      5   2007        WD         Normal     120500
# 1137       0     11   2008       New        Partial     394617
# 1138       0      4   2010        WD         Normal     149700
# 1139       0     11   2007        WD         Normal     197000
# 1140       0      9   2008        WD         Normal     191000
# 1141       0      5   2008        WD         Normal     149300
# 1142       0      4   2009        WD         Normal     310000
# 1143       0      5   2009        WD         Normal     121000
# 1144       0     11   2007        WD         Normal     179600
# 1145       0      5   2007        WD         Normal     129000
# 1146       0      4   2010        WD         Normal     157900
# 1147       0     12   2007        WD         Normal     240000
# 1148       0      5   2007        WD         Normal     112000
# 1149       0      8   2006        WD        Abnorml      92000
# 1150       0      9   2009        WD         Normal     136000
# 1151       0      5   2009       New        Partial     287090
# 1152       0      5   2006        WD         Normal     145000
# 1153       0      7   2006        WD        Abnorml      84500
# 1154       0     10   2009        WD         Normal     185000
# 1155       0      8   2007        WD         Normal     175000
# 1156       0      2   2010        WD         Normal     210000
# 1157    2500      5   2010        WD         Normal     266500
# 1158       0      4   2010        WD         Normal     142125
# 1159       0      6   2008        WD         Normal     147500
#
# [1160 rows x 81 columns]>

# %%
df_app.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1160.000000  1160.000000   951.000000    1160.000000  1160.000000
# mean    580.500000    57.577586    69.698212   10529.315517     6.094828
# std     335.007463    42.294451    24.431093   10017.493921     1.401826
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     290.750000    20.000000    59.000000    7526.250000     5.000000
# 50%     580.500000    50.000000    68.000000    9462.500000     6.000000
# 75%     870.250000    70.000000    80.000000   11618.250000     7.000000
# max    1160.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1160.000000  1160.000000   1160.000000  1153.000000  1160.000000
# mean      5.580172  1971.023276   1984.703448    98.450997   447.211207
# std       1.127178    30.395387     20.756362   170.741427   463.425727
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1966.000000     0.000000     0.000000
# 50%       5.000000  1972.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   157.000000   725.000000
# max       9.000000  2010.000000   2010.000000  1378.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1160.000000  1160.000000    1160.000000  1160.000000
# mean       ...          94.094828    46.465517      22.593966     1.953448
# std        ...         124.905312    67.816930      61.465492    19.831984
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    24.000000       0.000000     0.000000
# 75%        ...         168.000000    66.000000       0.000000     0.000000
# max        ...         736.000000   547.000000     386.000000   304.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1160.000000  1160.000000   1160.000000  1160.000000  1160.000000
# mean     15.300862     3.031034     49.150000     6.413793  2007.812069
# std      56.326041    42.500093    553.959843     2.675969     1.313312
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1160.000000
# mean   180756.519828
# std     80872.738245
# min     34900.000000
# 25%    129975.000000
# 50%    162000.000000
# 75%    213310.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
def plot_graph(X, y, x_axis, y_axis):
    mean_x = np.mean(X)
    mean_y = np.mean(y)
    m = len(X)
    numer = 0
    denom = 0
    for i in range(m):
        numer += (X[i] - mean_x)*(y[i]-mean_y)
        denom += (X[i] - mean_x) ** 2
    b1 = numer/denom
    b0 =mean_y - (b1*mean_x)
    print('intercept & conf: ', b1, b0)
    
    max_x = np.max(X) + 100
    min_x = np.min(X) - 100
    line_x = np.linspace(min_x, max_x, 1000)
    line_y = b0 + b1 * line_x

    plt.figure(figsize=(10,10))
    plt.ylabel(y_axis, fontsize=12)
    plt.xlabel(x_axis, fontsize=12)
    plt.plot(line_x, line_y, color='#58b970', label='Regression Line')
    plt.scatter(X, y)
    plt.title(x_axis+" vs "+y_axis)

# %%
#Covariance & corelation
def cov_cor(X, y):
    cov = np.cov(X, y)
    cor = np.corrcoef(X, y)
    print('covariance of x & y: ', cov[0, 1])
    print('corelation of x & y: ', cor[0, 1])

# %%
X_mulitple = df_app.drop(['MSZoning', 'Street', 'Alley',  'LotShape', 'LandContour', 'Utilities', 'LotConfig','LandSlope', 'HeatingQC', 'BsmtQual', 'MasVnrType',  'Neighborhood','Condition1','Condition2','BldgType','HouseStyle','LotConfig','LandSlope','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond','BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu','GarageType', 'GarageFinish', 'GarageQual','GarageCond', 'PavedDrive', 'PoolQC', 'RoofStyle','RoofMatl', 'Exterior1st', 'Exterior2nd', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'], axis=1)
X_multiple_test = df_app_test.drop(['MSZoning', 'Street', 'Alley',  'LotShape', 'LandContour', 'Utilities', 'LotConfig','LandSlope', 'HeatingQC', 'BsmtQual', 'MasVnrType',  'Neighborhood','Condition1','Condition2','BldgType','HouseStyle','LotConfig','LandSlope','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond','BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu','GarageType', 'GarageFinish', 'GarageQual','GarageCond', 'PavedDrive', 'PoolQC', 'RoofStyle','RoofMatl', 'Exterior1st', 'Exterior2nd', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'], axis=1)
y_sales = df_app.SalePrice
X_mulitple = X_mulitple.fillna(0)
X_multiple_test = X_multiple_test.fillna(0)

y_cov_arr = np.array(y_sales)

# %%
X_mulitple.hist(bins=80, figsize=(15,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
# correlation with Sales Price data

corr_matrix = X_mulitple.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.785860
# GrLivArea        0.699584
# GarageCars       0.629773
# TotalBsmtSF      0.615875
# 1stFlrSF         0.613279
# GarageArea       0.611001
# FullBath         0.568083
# YearBuilt        0.524433
# TotRmsAbvGrd     0.524348
# YearRemodAdd     0.503454
# MasVnrArea       0.483880
# Fireplaces       0.463771
# BsmtFinSF1       0.400403
# WoodDeckSF       0.331164
# 2ndFlrSF         0.307098
# OpenPorchSF      0.296409
# HalfBath         0.282331
# LotArea          0.259322
# GarageYrBlt      0.254134
# BsmtFullBath     0.230752
# BsmtUnfSF        0.206746
# LotFrontage      0.201577
# BedroomAbvGr     0.166532
# PoolArea         0.101214
# ScreenPorch      0.082721
# 3SsnPorch        0.074861
# MoSold           0.026938
# BsmtFinSF2      -0.002029
# MiscVal         -0.018954
# YrSold          -0.021396
# BsmtHalfBath    -0.023940
# Id              -0.032139
# LowQualFinSF    -0.041842
# OverallCond     -0.082975
# MSSubClass      -0.084022
# KitchenAbvGr    -0.128064
# EnclosedPorch   -0.135188
# Name: SalePrice, dtype: float64

# %%
attributes = ['OverallQual','GrLivArea','GarageCars','TotalBsmtSF','1stFlrSF','GarageArea','FullBath','YearBuilt','TotRmsAbvGrd','YearRemodAdd','MasVnrArea','Fireplaces','BsmtFinSF1','WoodDeckSF','2ndFlrSF']
scatter_matrix(X_mulitple[attributes], figsize=(15,15))
plt.savefig('matrix.png')

# %%
X_mulitple.plot(kind="scatter", x="GrLivArea", y="SalePrice", alpha=0.5)
plt.savefig('scatter.png')

# %%
X_mulitple = X_mulitple.drop('SalePrice',axis=1)
onehot_train_X = pd.get_dummies(X_mulitple)
onehot_test_X = pd.get_dummies(X_multiple_test)
train_X, test_X = onehot_train_X.align(onehot_test_X, join='left', axis=1)

# %%
# Linear regression 
regressor = LinearRegression()
regressor.fit(train_X, y_sales)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Calculate R squared
y_pred = regressor.predict(test_X)


# creating the submission file
my_submission = pd.DataFrame({'Id': test_X.Id, 'SalePrice':y_pred})
my_submission.to_csv('submission.csv', index=False)
print('Linear Regression R squared": ',  regressor.score(X_test, y_test))
# Out:
# Linear Regression R squared":  0.7212109201384689

# %%
#Calculate root-mean-square error (RMSE)

lin_mse = mean_squared_error(y_pred, y_test)
lin_rmse = np.sqrt(lin_mse)
print('Linear Regression RMSE: ', lin_rmse)
# Out:
# Linear Regression RMSE:  50837.007751845034

# %%
#Calculate mean absolute error (MAE):

lin_mae = mean_absolute_error(y_pred, y_test)
print('Linear Regression MAE: ' ,  lin_mae)
# Out:
# Linear Regression MAE:  23706.52192537047

# %%
# X_test.size ==y_test.size

# %%
# plt.scatter(X_test.values, y_test.values,  color='black')
# plt.plot(X_test.values, y_pred.values, color='blue', linewidth=3)

# plt.xticks(())
# plt.yticks(())

# plt.show()
